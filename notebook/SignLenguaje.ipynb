# %% [markdown]
# ### CNN Sign Lenguaje

# %% [markdown]
# #### Importo las librerias centrales

# %%
import os
from pathlib import Path
os.chdir(Path(os.getcwd()).resolve().parent)

from main import Main
from config import ModelNames

main = Main()

# %% [markdown]
# #### Separo las imagenes a carpetas de Train, Validation y Test

# %%
main.preprocess_images(train_size=0.8, val_size=0.15)
# Out:
# -. Pre procesando datos...
# Copiando imagenes hacia Train/Test: 100%|██████████| 10/10 [00:03<00:00,  2.86it/s]

# %% [markdown]
# #### Visualizo las imagenes en Train

# %%
main.visualize_train_images()
# Out:
# -. Generando imagenes...
#
# -. Imagenes Reales para entrenamiento...
# Carpeta '0': 164 elementos
# Carpeta '1': 164 elementos
# Carpeta '2': 164 elementos
# Carpeta '3': 164 elementos
# Carpeta '4': 165 elementos
# Carpeta '5': 165 elementos
# Carpeta '6': 165 elementos
# Carpeta '7': 165 elementos
# Carpeta '8': 166 elementos
# Carpeta '9': 163 elementos

# %% [markdown]
# #### Primer Modelo: Entrenamiento con images crudas

# %%
raw_model = main.execute_model(version=ModelNames.RAW)
# Out:
# -. Realizando entrenamiento con modelo RAW...
# Found 1645 files belonging to 10 classes.
# Found 347 files belonging to 10 classes.
# Epoch 1/40
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 14s 217ms/step - accuracy: 0.2772 - loss: 10.0789 - val_accuracy: 0.6225 - val_loss: 1.2052
# Epoch 2/40
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 9s 168ms/step - accuracy: 0.6748 - loss: 0.9552 - val_accuracy: 0.7752 - val_loss: 0.6744
# Epoch 3/40
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 9s 175ms/step - accuracy: 0.7891 - loss: 0.6127 - val_accuracy: 0.8329 - val_loss: 0.5076
# Epoch 4/40
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 8s 161ms/step - accuracy: 0.8073 - loss: 0.5267 - val_accuracy: 0.8271 - val_loss: 0.5059
# Epoch 5/40
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.8717 - loss: 0.4004 - val_accuracy: 0.8588 - val_loss: 0.4316
# Epoch 6/40
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 114ms/step - accuracy: 0.8705 - loss: 0.3720 - val_accuracy: 0.8761 - val_loss: 0.4266
# Epoch 7/40
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 114ms/step - accuracy: 0.8888 - loss: 0.3121 - val_accuracy: 0.8674 - val_loss: 0.4369
# Epoch 8/40
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 110ms/step - accuracy: 0.9076 - loss: 0.2780 - val_accuracy: 0.8559 - val_loss: 0.4068
# Epoch 9/40
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 107ms/step - accuracy: 0.9106 - loss: 0.2679 - val_accuracy: 0.8732 - val_loss: 0.4121
# Epoch 10/40
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 106ms/step - accuracy: 0.9283 - loss: 0.2153 - val_accuracy: 0.8646 - val_loss: 0.4498
# Epoch 11/40
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 106ms/step - accuracy: 0.9283 - loss: 0.1982 - val_accuracy: 0.8617 - val_loss: 0.5242

# %% [markdown]
# #### Segundo modelo: Entrenamiento con imagenes crudas + Transfer Learning

# %%
tl_model = main.execute_model(version=ModelNames.TRANSFER_LEARNING, use_tl=True)
# Out:
# -. Realizando entrenamiento con modelo TL...
# Found 1645 files belonging to 10 classes.
# Found 347 files belonging to 10 classes.
# Epoch 1/40
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 51s 969ms/step - accuracy: 0.5672 - loss: 6.5165 - val_accuracy: 0.8559 - val_loss: 0.9348
# Epoch 2/40
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 61s 1s/step - accuracy: 0.8383 - loss: 1.4924 - val_accuracy: 0.8876 - val_loss: 0.8371
# Epoch 3/40
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 63s 1s/step - accuracy: 0.9046 - loss: 0.7960 - val_accuracy: 0.9049 - val_loss: 0.7536
# Epoch 4/40
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9283 - loss: 0.5173 - val_accuracy: 0.8991 - val_loss: 0.8337
# Epoch 5/40
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9374 - loss: 0.3895 - val_accuracy: 0.9020 - val_loss: 0.8491
# Epoch 6/40
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9435 - loss: 0.4053 - val_accuracy: 0.8991 - val_loss: 0.8043
# Epoch 7/40
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 60s 1s/step - accuracy: 0.9465 - loss: 0.3795 - val_accuracy: 0.8847 - val_loss: 1.2014
# Epoch 8/40
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 58s 1s/step - accuracy: 0.9635 - loss: 0.2147 - val_accuracy: 0.8991 - val_loss: 1.0922

# %% [markdown]
# #### Aplico Data Augmentation

# %%
main.apply_data_augmentation()
# Out:
# -. Aplicando Data Augmentation...
# Found 1645 files belonging to 10 classes.
# Aumentando Dataset: 100%|██████████| 1645/1645 [02:03<00:00, 13.34it/s]

# %% [markdown]
# #### Tercer Modelo: Entrenamiento post Data Augmentation

# %%
augm_model = main.execute_model(version=ModelNames.DATA_AUGMENTATION)
# Out:
# -. Realizando entrenamiento con modelo AUGMENTATION...
# Found 9870 files belonging to 10 classes.
# Found 347 files belonging to 10 classes.
# Epoch 1/40
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 41s 129ms/step - accuracy: 0.2576 - loss: 4.1466 - val_accuracy: 0.7262 - val_loss: 0.9468
# Epoch 2/40
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 34s 112ms/step - accuracy: 0.4553 - loss: 1.5788 - val_accuracy: 0.7925 - val_loss: 0.6290
# Epoch 3/40
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 36s 116ms/step - accuracy: 0.5822 - loss: 1.1812 - val_accuracy: 0.8271 - val_loss: 0.4795
# Epoch 4/40
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 36s 118ms/step - accuracy: 0.6716 - loss: 0.9328 - val_accuracy: 0.8473 - val_loss: 0.4501
# Epoch 5/40
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 38s 123ms/step - accuracy: 0.7408 - loss: 0.7281 - val_accuracy: 0.9193 - val_loss: 0.2533
# Epoch 6/40
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 38s 124ms/step - accuracy: 0.7949 - loss: 0.5810 - val_accuracy: 0.8934 - val_loss: 0.2714
# Epoch 7/40
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 39s 125ms/step - accuracy: 0.8356 - loss: 0.4655 - val_accuracy: 0.9193 - val_loss: 0.2240
# Epoch 8/40
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 39s 127ms/step - accuracy: 0.8546 - loss: 0.4130 - val_accuracy: 0.9308 - val_loss: 0.2105
# Epoch 9/40
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 39s 127ms/step - accuracy: 0.8788 - loss: 0.3476 - val_accuracy: 0.8905 - val_loss: 0.2566
# Epoch 10/40
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 39s 126ms/step - accuracy: 0.8872 - loss: 0.3144 - val_accuracy: 0.9222 - val_loss: 0.1952
# Epoch 11/40
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 39s 128ms/step - accuracy: 0.9023 - loss: 0.2856 - val_accuracy: 0.9366 - val_loss: 0.2035
# Epoch 12/40
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 40s 128ms/step - accuracy: 0.9131 - loss: 0.2501 - val_accuracy: 0.9539 - val_loss: 0.1239
# Epoch 13/40
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 44s 142ms/step - accuracy: 0.9229 - loss: 0.2224 - val_accuracy: 0.9251 - val_loss: 0.2259
# Epoch 14/40
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 40s 130ms/step - accuracy: 0.9299 - loss: 0.2079 - val_accuracy: 0.9135 - val_loss: 0.2479
# Epoch 15/40
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 39s 125ms/step - accuracy: 0.9362 - loss: 0.1888 - val_accuracy: 0.9337 - val_loss: 0.1767
# Epoch 16/40
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 37s 118ms/step - accuracy: 0.9378 - loss: 0.1834 - val_accuracy: 0.9424 - val_loss: 0.1712
# Epoch 17/40
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 37s 119ms/step - accuracy: 0.9455 - loss: 0.1642 - val_accuracy: 0.9481 - val_loss: 0.1434

# %% [markdown]
# #### Cuarto Modelo: Entrenamiento post Data Augmentation + Transfer Learning

# %%
tlaugm_model = main.execute_model(version=ModelNames.TRANSFER_AND_AUGMENTATION, use_tl=True)
# Out:
# -. Realizando entrenamiento con modelo TLAUGM...
# Found 9870 files belonging to 10 classes.
# Found 347 files belonging to 10 classes.
# Epoch 1/40
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 298s 964ms/step - accuracy: 0.6174 - loss: 5.8215 - val_accuracy: 0.9049 - val_loss: 0.7583
# Epoch 2/40
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 319s 1s/step - accuracy: 0.7876 - loss: 2.5811 - val_accuracy: 0.8818 - val_loss: 0.9614
# Epoch 3/40
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 300s 971ms/step - accuracy: 0.8388 - loss: 1.8301 - val_accuracy: 0.9107 - val_loss: 0.7652
# Epoch 4/40
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 299s 969ms/step - accuracy: 0.8527 - loss: 1.6040 - val_accuracy: 0.9337 - val_loss: 0.7050
# Epoch 5/40
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 300s 970ms/step - accuracy: 0.8762 - loss: 1.3432 - val_accuracy: 0.9337 - val_loss: 1.0201
# Epoch 6/40
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 300s 970ms/step - accuracy: 0.8829 - loss: 1.2238 - val_accuracy: 0.9135 - val_loss: 1.1582
# Epoch 7/40
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 299s 969ms/step - accuracy: 0.8899 - loss: 1.2221 - val_accuracy: 0.9308 - val_loss: 0.6918
# Epoch 8/40
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 308s 996ms/step - accuracy: 0.9020 - loss: 1.1719 - val_accuracy: 0.9164 - val_loss: 0.7724
# Epoch 9/40
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 312s 1s/step - accuracy: 0.9033 - loss: 1.1188 - val_accuracy: 0.9424 - val_loss: 0.7861
# Epoch 10/40
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 310s 1s/step - accuracy: 0.9059 - loss: 1.1352 - val_accuracy: 0.9337 - val_loss: 0.9476
# Epoch 11/40
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 303s 979ms/step - accuracy: 0.9131 - loss: 1.0840 - val_accuracy: 0.9164 - val_loss: 0.9986
# Epoch 12/40
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 300s 971ms/step - accuracy: 0.9124 - loss: 1.1380 - val_accuracy: 0.9452 - val_loss: 0.8716
# Epoch 13/40
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 300s 970ms/step - accuracy: 0.9218 - loss: 0.9977 - val_accuracy: 0.9337 - val_loss: 1.0255
# Epoch 14/40
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 300s 971ms/step - accuracy: 0.9237 - loss: 1.0226 - val_accuracy: 0.9308 - val_loss: 1.1730
# Epoch 15/40
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 300s 971ms/step - accuracy: 0.9227 - loss: 1.0881 - val_accuracy: 0.9308 - val_loss: 1.1057
# Epoch 16/40
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 309s 998ms/step - accuracy: 0.9245 - loss: 1.0157 - val_accuracy: 0.9366 - val_loss: 1.0231
# Epoch 17/40
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 305s 987ms/step - accuracy: 0.9300 - loss: 0.9890 - val_accuracy: 0.9337 - val_loss: 1.1282

# %% [markdown]
# #### Comparacion entre modelos

# %%
main.evaluate_model(ModelNames.RAW)
main.evaluate_model(ModelNames.TRANSFER_LEARNING)
main.evaluate_model(ModelNames.DATA_AUGMENTATION)
main.evaluate_model(ModelNames.TRANSFER_AND_AUGMENTATION)
# Out:
# -. Evaluando resultados del mejor modelo RAW...
# Found 347 files belonging to 10 classes.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.8761 - loss: 0.4266
#    -. Val loss: 0.4266481399536133
#    -. Val accuracy: 0.8760806918144226
# -. Evaluando resultados del mejor modelo TL...
# Found 347 files belonging to 10 classes.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 896ms/step - accuracy: 0.9049 - loss: 0.7536
#    -. Val loss: 0.7535609006881714
#    -. Val accuracy: 0.9048991203308105
# -. Evaluando resultados del mejor modelo AUGMENTATION...
# Found 347 files belonging to 10 classes.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.9539 - loss: 0.1239
#    -. Val loss: 0.12389174848794937
#    -. Val accuracy: 0.9538905024528503
# -. Evaluando resultados del mejor modelo TLAUGM...
# Found 347 files belonging to 10 classes.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 915ms/step - accuracy: 0.9452 - loss: 0.8716
#    -. Val loss: 0.8716201782226562
#    -. Val accuracy: 0.9452449679374695

# %% [markdown]
# #### Prediccion sobre imagenes en Test

# %%
preds = main.predict(ModelNames.DATA_AUGMENTATION, plot=True)
# Out:
# -. Cargando modelo AUGMENTATION y evaluando sobre Test...
